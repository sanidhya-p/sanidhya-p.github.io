# %% [markdown]
# <a href="https://colab.research.google.com/github/sanidhya-p/sanidhya-p.github.io/blob/main/Predicting_the_weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
weather = pd.read_csv('/content/2915984.csv', index_col ='DATE')

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-03-16  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-03-17  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-03-18  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-03-19  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-03-20  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
weather.loc['2001-01-01':'2002-01-01']
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 2001-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2001-12-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-12-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-12-30  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2001-12-31  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2002-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
weather.isna().sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.654426
# ACSH       0.654426
# AWND       0.520785
# DAPR       0.999527
# FMTM       0.870498
# FRGT       0.999882
# MDPR       0.999527
# PGTM       0.496659
# PRCP       0.016616
# SNOW       0.327065
# SNWD       0.319733
# TAVG       0.879546
# TMAX       0.000532
# TMIN       0.000591
# TSUN       0.931938
# WDF1       0.654426
# WDF2       0.520726
# WDF5       0.525871
# WDFG       0.747679
# WSF1       0.654426
# WSF2       0.520667
# WSF5       0.525871
# WSFG       0.747679
# WT01       0.779256
# WT02       0.980072
# WT03       0.992904
# WT04       0.999763
# WT05       0.998344
# WT07       0.999882
# WT08       0.810538
# WT09       0.999882
# WT16       0.884395
# WT18       0.999823
# dtype: float64

# %%
weather.shape[0]
# Out:
# 16911

# %%
core_weather = weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
core_weather
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1960-01-01  0.00   0.0   0.0  49.0  30.0
# 1960-01-02  0.00   0.0   0.0  49.0  29.0
# 1960-01-03  0.00   0.0   0.0  54.0  35.0
# 1960-01-04  0.00   0.0   0.0  54.0  36.0
# 1960-01-05  0.00   0.0   0.0  55.0  33.0
# ...          ...   ...   ...   ...   ...
# 2022-03-16  0.00   NaN   NaN  64.0  45.0
# 2022-03-17  0.00   NaN   NaN  60.0  48.0
# 2022-03-18  0.00   NaN   NaN  67.0  43.0
# 2022-03-19  0.01   NaN   NaN  58.0  50.0
# 2022-03-20  0.00   NaN   NaN  64.0  45.0
#
# [16911 rows x 5 columns]

# %%
core_weather.columns = ["precip","snow","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01    0.00   0.0         0.0      49.0      30.0
# 1960-01-02    0.00   0.0         0.0      49.0      29.0
# 1960-01-03    0.00   0.0         0.0      54.0      35.0
# 1960-01-04    0.00   0.0         0.0      54.0      36.0
# 1960-01-05    0.00   0.0         0.0      55.0      33.0
# ...            ...   ...         ...       ...       ...
# 2022-03-16    0.00   NaN         NaN      64.0      45.0
# 2022-03-17    0.00   NaN         NaN      60.0      48.0
# 2022-03-18    0.00   NaN         NaN      67.0      43.0
# 2022-03-19    0.01   NaN         NaN      58.0      50.0
# 2022-03-20    0.00   NaN         NaN      64.0      45.0
#
# [16911 rows x 5 columns]

# %%
core_weather.isna().sum()
# Out:
# precip         281
# snow          5531
# snow_depth    5407
# temp_max         9
# temp_min        10
# dtype: int64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    11379
# 1.0        1
# Name: snow, dtype: int64

# %%
# there is only one day which has snowed which isnt useful for our ML model so we delete it

# %%
del core_weather["snow"]

# %%
core_weather
# Out:
#             precip  snow_depth  temp_max  temp_min
# DATE
# 1960-01-01    0.00         0.0      49.0      30.0
# 1960-01-02    0.00         0.0      49.0      29.0
# 1960-01-03    0.00         0.0      54.0      35.0
# 1960-01-04    0.00         0.0      54.0      36.0
# 1960-01-05    0.00         0.0      55.0      33.0
# ...            ...         ...       ...       ...
# 2022-03-16    0.00         NaN      64.0      45.0
# 2022-03-17    0.00         NaN      60.0      48.0
# 2022-03-18    0.00         NaN      67.0      43.0
# 2022-03-19    0.01         NaN      58.0      50.0
# 2022-03-20    0.00         NaN      64.0      45.0
#
# [16911 rows x 4 columns]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    11504
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2013-12-15     NaN      58.0      33.0
# 2016-05-01     NaN      80.0      55.0
# 2016-05-02     NaN      68.0      53.0
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
#
# [281 rows x 3 columns]

# %%
core_weather.loc["1983-10-01":"1983-11-20"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-01    0.27      72.0      59.0
# 1983-10-02    0.00      69.0      60.0
# 1983-10-03    0.00      75.0      54.0
# 1983-10-04    0.00      80.0      58.0
# 1983-10-05    0.00      76.0      58.0
# 1983-10-06    0.00      74.0      60.0
# 1983-10-07    0.00      69.0      58.0
# 1983-10-08    0.00      70.0      59.0
# 1983-10-09    0.00      73.0      61.0
# 1983-10-10    0.00      74.0      58.0
# 1983-10-11    0.00      75.0      59.0
# 1983-10-12    0.00      75.0      59.0
# 1983-10-13    0.00      70.0      58.0
# 1983-10-14    0.00      70.0      54.0
# 1983-10-15    0.00      69.0      54.0
# 1983-10-16    0.00      65.0      54.0
# 1983-10-17    0.00      68.0      54.0
# 1983-10-18    0.00      67.0      56.0
# 1983-10-19    0.00      69.0      52.0
# 1983-10-20    0.00      73.0      52.0
# 1983-10-21    0.00      70.0      50.0
# 1983-10-22    0.00      70.0      50.0
# 1983-10-23    0.00      69.0      60.0
# ...

# %%
core_weather['precip'].value_counts()
# Out:
# 0.00    13710
# 0.01      440
# 0.02      199
# 0.03      123
# 0.04      103
#         ...
# 1.29        1
# 1.73        1
# 1.05        1
# 1.38        1
# 1.02        1
# Name: precip, Length: 176, dtype: int64

# %%
core_weather['precip'] = core_weather['precip'].fillna(0)

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []

# %%
core_weather.isna().sum()
# Out:
# precip       0
# temp_max     9
# temp_min    10
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN

# %%
core_weather["2004-11-20":"2004-12-10"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20    0.00       NaN       NaN
# 2004-11-21    0.00      64.0      44.0
# 2004-11-22    0.00      62.0      37.0
# 2004-11-23    0.00      58.0      40.0
# 2004-11-24    0.00      60.0      39.0
# 2004-11-25    0.01      57.0      47.0
# 2004-11-26    0.00      59.0      45.0
# 2004-11-27    0.18      61.0      49.0
# 2004-11-28    0.00      59.0      42.0
# 2004-11-29    0.00      56.0      34.0
# 2004-11-30    0.00      53.0      31.0
# 2004-12-01    0.00      55.0      33.0
# 2004-12-02    0.00      60.0      33.0
# 2004-12-03    0.00      56.0      36.0
# 2004-12-04    0.00      54.0      30.0
# 2004-12-05    0.00      53.0      37.0
# 2004-12-06    0.20      55.0      40.0
# 2004-12-07    0.72      59.0      49.0
# 2004-12-08    1.27      57.0      52.0
# 2004-12-09    0.01      61.0      49.0
# 2004-12-10    0.02      57.0      47.0

# %%
core_weather['temp_min'].mean()
# Out:
# 50.40565647003136

# %%
core_weather = core_weather.fillna(method="ffill")
## ff fill does fill the value of prev row

# %%
core_weather.isna().sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %% [markdown]
# ### Verifying we have correct data types

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04', '1960-01-05',
#        '1960-01-06', '1960-01-07', '1960-01-08', '1960-01-09', '1960-01-10',
#        ...
#        '2022-03-11', '2022-03-12', '2022-03-13', '2022-03-14', '2022-03-15',
#        '2022-03-16', '2022-03-17', '2022-03-18', '2022-03-19', '2022-03-20'],
#       dtype='object', name='DATE', length=16911)

# %%
core_weather.index =pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2022-03-11', '2022-03-12', '2022-03-13', '2022-03-14',
#                '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18',
#                '2022-03-19', '2022-03-20'],
#               dtype='datetime64[ns]', name='DATE', length=16911, freq=None)

# %%
core_weather.index.year
# Out:
# Int64Index([1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960, 1960,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='DATE', length=16911)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[['temp_max','temp_min']].plot()

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1960    366
# 1961    365
# 1962    365
# 1963    365
# 1964    366
# 1965    365
# 1966    365
# 1967    365
# 1968    366
# 1969    365
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022     79
# Name: DATE, dtype: int64

# %%
core_weather['precip'].plot()

# %%
core_weather.groupby(core_weather.index.year).sum()['precip']
# Out:
# DATE
# 1960    14.01
# 1961    13.87
# 1962    22.47
# 1963    19.11
# 1964    16.83
# 1965    16.32
# 1966    13.11
# 1967    23.98
# 1968    17.19
# 1969    25.70
# 1970    25.31
# 1971    10.61
# 1972    16.27
# 1973    29.37
# 1974    16.87
# 1975    17.54
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983     7.13
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.84
# 2002    19.12
# 2003    11.37
# 2004    12.97
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.77
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022     0.51
# Name: precip, dtype: float64

# %% [markdown]
# ## Model **Training**

# %%
core_weather['target']= core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00      49.0      30.0    49.0
# 1960-01-02    0.00      49.0      29.0    54.0
# 1960-01-03    0.00      54.0      35.0    54.0
# 1960-01-04    0.00      54.0      36.0    55.0
# 1960-01-05    0.00      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-03-16    0.00      64.0      45.0    60.0
# 2022-03-17    0.00      60.0      48.0    67.0
# 2022-03-18    0.00      67.0      43.0    58.0
# 2022-03-19    0.01      58.0      50.0    64.0
# 2022-03-20    0.00      64.0      45.0     NaN
#
# [16911 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1960-01-01    0.00      49.0      30.0    49.0
# 1960-01-02    0.00      49.0      29.0    54.0
# 1960-01-03    0.00      54.0      35.0    54.0
# 1960-01-04    0.00      54.0      36.0    55.0
# 1960-01-05    0.00      55.0      33.0    53.0
# ...            ...       ...       ...     ...
# 2022-03-15    0.12      64.0      51.0    64.0
# 2022-03-16    0.00      64.0      45.0    60.0
# 2022-03-17    0.00      60.0      48.0    67.0
# 2022-03-18    0.00      67.0      43.0    58.0
# 2022-03-19    0.01      58.0      50.0    64.0
#
# [16910 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha =.1)
# Ridge minimizes corecurring

# %%
predictors = ['precip','temp_max','temp_min']

# %%
train = core_weather.loc[:"2020-12-31"]

# %%
test = core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors],train['target'])
# Out:
# Ridge(alpha=0.1)

# %%
predictons =reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test['target'],predictons)
# Out:
# 3.4313042065195023

# %%
combined = pd.concat([test['target'],pd.Series(predictons, index= test.index)],axis=1)
combined.columns =['actual','predictions' ]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    57.0    59.806024
# 2021-01-02    56.0    59.310181
# 2021-01-03    62.0    58.538685
# 2021-01-04    59.0    61.531814
# 2021-01-05    59.0    59.444266
# ...            ...          ...
# 2022-03-15    64.0    64.402296
# 2022-03-16    60.0    63.589030
# 2022-03-17    67.0    61.243548
# 2022-03-18    58.0    65.393064
# 2022-03-19    64.0    60.138579
#
# [443 rows x 2 columns]

# %%
combined.plot()

# %%
reg.coef_
# Out:
# array([-2.20730384,  0.72113834,  0.17969047])

# %%
def create_predictions(predictors, core_weather, reg):
  train= core_weather.loc[:"2020-12-31"]
  test = core_weather.loc["2021-01-01":]
  reg.fit(train[predictors],train['target'])
  predictons =reg.predict(test[predictors])
  error = mean_absolute_error(test['target'],predictons)
  combined = pd.concat([test['target'],pd.Series(predictons, index= test.index)],axis=1)
  combined.columns =['actual','predictions']
  return error, combined

# %%
core_weather['month_max'] = core_weather['temp_max'].rolling(30).mean()
# to find the mean 30 days before that particular day

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 1960-01-01    0.00      49.0      30.0    49.0        NaN
# 1960-01-02    0.00      49.0      29.0    54.0        NaN
# 1960-01-03    0.00      54.0      35.0    54.0        NaN
# 1960-01-04    0.00      54.0      36.0    55.0        NaN
# 1960-01-05    0.00      55.0      33.0    53.0        NaN
# ...            ...       ...       ...     ...        ...
# 2022-03-15    0.12      64.0      51.0    64.0  62.600000
# 2022-03-16    0.00      64.0      45.0    60.0  62.900000
# 2022-03-17    0.00      60.0      48.0    67.0  62.866667
# 2022-03-18    0.00      67.0      43.0    58.0  62.866667
# 2022-03-19    0.01      58.0      50.0    64.0  62.566667
#
# [16910 rows x 5 columns]

# %%
# for the given day how our mean temprature is differ from given day
core_weather['month_day_max']= core_weather['month_max'] / core_weather['temp_max']

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max
# DATE
# 1960-01-01    0.00      49.0      30.0    49.0        NaN            NaN
# 1960-01-02    0.00      49.0      29.0    54.0        NaN            NaN
# 1960-01-03    0.00      54.0      35.0    54.0        NaN            NaN
# 1960-01-04    0.00      54.0      36.0    55.0        NaN            NaN
# 1960-01-05    0.00      55.0      33.0    53.0        NaN            NaN
# ...            ...       ...       ...     ...        ...            ...
# 2022-03-15    0.12      64.0      51.0    64.0  62.600000       0.978125
# 2022-03-16    0.00      64.0      45.0    60.0  62.900000       0.982812
# 2022-03-17    0.00      60.0      48.0    67.0  62.866667       1.047778
# 2022-03-18    0.00      67.0      43.0    58.0  62.866667       0.938308
# 2022-03-19    0.01      58.0      50.0    64.0  62.566667       1.078736
#
# [16910 rows x 6 columns]

# %%
core_weather['max_min']= core_weather['temp_max'] / core_weather['temp_min']

# %%
predictors = ['precip','temp_max','temp_min','month_max','month_day_max','max_min']

# %%
core_weather = core_weather.iloc[30:,:].copy()

# %%
error, combined = create_predictions(predictors,core_weather, reg)

# %%
error
# Out:
# 3.3753031689746975

# %%
combined.plot()

# %%
core_weather['monthly_avg'] = core_weather['temp_max'].groupby(core_weather.index.month).apply(lambda x: x.expanding(1).mean())

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1960-01-31    0.00      59.0      46.0    62.0  55.566667       0.941808
# 1960-02-01    0.81      62.0      51.0    59.0  56.000000       0.903226
# 1960-02-02    0.00      59.0      43.0    59.0  56.166667       0.951977
# 1960-02-03    0.20      59.0      47.0    60.0  56.333333       0.954802
# 1960-02-04    0.16      60.0      42.0    60.0  56.500000       0.941667
# ...            ...       ...       ...     ...        ...            ...
# 2022-03-15    0.12      64.0      51.0    64.0  62.600000       0.978125
# 2022-03-16    0.00      64.0      45.0    60.0  62.900000       0.982812
# 2022-03-17    0.00      60.0      48.0    67.0  62.866667       1.047778
# 2022-03-18    0.00      67.0      43.0    58.0  62.866667       0.938308
# 2022-03-19    0.01      58.0      50.0    64.0  62.566667       1.078736
#
#              max_min  monthly_avg  day_of_year_avg
# DATE
# ...

# %%
core_weather['day_of_year_avg'] = core_weather['temp_max'].groupby(core_weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())

# %%
predictors = ['precip','temp_max','temp_min','month_max','month_day_max','max_min','day_of_year_avg','monthly_avg']

# %%
error, combined = create_predictions(predictors,core_weather, reg)

# %%
error
# Out:
# 3.340492257909574

# %%
combined.plot()

# %%
reg.coef_
# Out:
# array([ -0.90804013,   0.40146278,   0.03114081,   0.33672074,
#        -15.97061869,   0.0493612 ,   0.08006707,   0.14343362])

# %%
core_weather.corr()['target']
# Out:
# precip            -0.205066
# temp_max           0.821361
# temp_min           0.594917
# target             1.000000
# month_max          0.686464
# month_day_max     -0.421383
# max_min            0.045111
# monthly_avg        0.689370
# day_of_year_avg    0.711876
# Name: target, dtype: float64

# %%
combined['diff']= (combined['actual']-combined['predictions']).abs()

# %%
combined.sort_values("diff",ascending=False).head()
# Out:
#             actual  predictions       diff
# DATE
# 2021-01-17    83.0    68.585837  14.414163
# 2021-05-07    81.0    67.774432  13.225568
# 2021-04-01    62.0    75.178360  13.178360
# 2021-02-22    84.0    71.168844  12.831156
# 2021-10-16    66.0    78.823197  12.823197
